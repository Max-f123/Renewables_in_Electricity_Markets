# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#set settings for plots
plt.rcParams['figure.figsize'] = [10, 5]
plt.rcParams['figure.dpi'] = 500

# %%
profits = pd.read_csv('1_1_results/profits_1_1.csv')

#make a latex table with the profits.describe() values
print(profits.describe().to_latex())
# Out:
# \begin{tabular}{lrr}
# \toprule
#  & scenario & profit \\
# \midrule
# count & 250.000000 & 250.000000 \\
# mean & 125.500000 & 199651.903317 \\
# std & 72.312977 & 154529.868022 \\
# min & 1.000000 & 4451.238397 \\
# 25% & 63.250000 & 55704.352615 \\
# 50% & 125.500000 & 181385.632570 \\
# 75% & 187.750000 & 300397.419440 \\
# max & 250.000000 & 621493.642146 \\
# \bottomrule
# \end{tabular}

# %%
#make good looking histogram of profits
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.hist(profits['profit'], bins=20)


#save plot
plt.savefig('1_1_results/profits_histogram.png')
