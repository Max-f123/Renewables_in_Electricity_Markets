# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#set settings for plots
plt.rcParams['figure.figsize'] = [10, 5]
plt.rcParams['figure.dpi'] = 500

# %%
profits = pd.read_csv('1_1_results/profits_1_1.csv')

#make a latex table with the profits.describe() values
print(profits['profit'].describe().to_latex())
# Out:
# \begin{tabular}{lr}
# \toprule
#  & profit \\
# \midrule
# count & 250.000000 \\
# mean & 151705.658298 \\
# std & 112615.203718 \\
# min & 4327.314409 \\
# 25% & 64443.740250 \\
# 50% & 129557.094072 \\
# 75% & 215005.218896 \\
# max & 603857.042146 \\
# \bottomrule
# \end{tabular}

# %%
profits = pd.read_csv('1_1_results/profits_1_1.csv')
#make good looking histogram of profits
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.hist(profits['profit'], bins=250)
plt.savefig('1_1_results/profits_histogram.png')
